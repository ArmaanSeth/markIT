# %%
from langchain_google_genai.chat_models import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage
import cv2
import base64

# %%
vision_llm = ChatGoogleGenerativeAI(model="gemini-pro-vision", google_api_key="AIzaSyAuJGRvMXS2nyxRwwi2Hv8E-tnLAffr0lQ")
def encode(img):
  with open(img,'rb') as f:
    return base64.b64encode(f.read()).decode('utf-8')

impath="C:\\Users\\Armaan\\Downloads\\1.jpg"
img=encode(impath)
s=str(cv2.imread(impath).shape)
prompt = f'return the pixel coordinates of the bounding box for the product in the image if the size of image is {s}'
message = HumanMessage(
    content=[
        {"type":"text", "text":f"Here is an image. {prompt}"},
        {"type":"image_url","image_url":{
                  "url":f'data:image/jpeg;base64,{img}'
              }}
    ]
)
response = vision_llm.invoke([message])
print(response.content)

# %%
img=cv2.imread(impath)
img=cv2.rectangle(img, (220, 390), (780, 950), (0,255,0), 2)
cv2.imshow("image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
str(img.shape)

# %%
import cv2
from PIL import Image, ImageDraw, ImageFont
import numpy as np

def add_text_avoiding_bbox(image_path, bbox, text, font_path="arial.ttf", max_font_size=50, min_font_size=10):
    # Load the image using OpenCV
    image = cv2.imread(image_path)
    height, width, _ = image.shape

    # Extract bounding box coordinates
    x, y, w, h = bbox

    # Convert image to PIL format
    image_pil = Image.fromarray(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    draw = ImageDraw.Draw(image_pil)

    # Find the largest possible font size that fits within the available space
    for font_size in range(max_font_size, min_font_size - 1, -1):
        font = ImageFont.truetype(font_path, font_size)
        text_bbox = draw.textbbox((0, 0), text, font=font)
        text_width, text_height = text_bbox[2] - text_bbox[0], text_bbox[3] - text_bbox[1]

        # Positions to consider (top-left, top-right, bottom-left, bottom-right)
        positions = [
            (10, 10),  # Top-left
            (width - text_width - 10, 10),  # Top-right
            (10, height - text_height - 10),  # Bottom-left
            (width - text_width - 10, height - text_height - 10)  # Bottom-right
        ]

        # Select the first position that does not overlap the bounding box
        for pos in positions:
            tx, ty = pos
            if not (tx < x + w and tx + text_width > x and ty < y + h and ty + text_height > y):
                text_position = pos
                draw.text(text_position, text, font=font, fill="black")
                # Convert image back to OpenCV format and save it
                image = cv2.cvtColor(np.array(image_pil), cv2.COLOR_RGB2BGR)
                cv2.imshow("image", image)
                cv2.waitKey(0)
                cv2.destroyAllWindows()
                return

# Example usage
image_path = impath
bbox = (220, 390, 780, 950)  # Example bounding box (x, y, width, height)
text = "Sip in Style"

add_text_avoiding_bbox(image_path, bbox, text)

# %%
import cv2
from PIL import Image, ImageDraw, ImageFont
import numpy as np

def add_text_avoiding_bbox(image_path, bbox, text, font_path="arial.ttf", max_font_size=50, min_font_size=10):
    # Load the image using OpenCV
    image = cv2.imread(image_path)
    height, width, _ = image.shape

    # Extract bounding box coordinates
    x, y, w, h = bbox

    # Convert image to PIL format
    image_pil = Image.fromarray(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    draw = ImageDraw.Draw(image_pil)

    # Find the largest possible font size that fits within the available space
    for font_size in range(max_font_size, min_font_size - 1, -1):
        font = ImageFont.truetype(font_path, font_size)
        text_bbox = draw.textbbox((0, 0), text, font=font)
        text_width, text_height = text_bbox[2] - text_bbox[0], text_bbox[3] - text_bbox[1]

        # Determine available space above, below, left, and right of the bounding box
        spaces = [
            ("top", 10, 10, width - 20, y - 20),  # Top space
            ("bottom", 10, y + h + 10, width - 20, height - (y + h + 20)),  # Bottom space
            ("left", 10, 10, x - 20, height - 20),  # Left space
            ("right", x + w + 10, 10, width - (x + w + 20), height - 20)  # Right space
        ]

        for space in spaces:
            position, tx, ty, avail_width, avail_height = space
            if text_width <= avail_width and text_height <= avail_height:
                text_position = (tx, ty)
                draw.text(text_position, text, font=font, fill="black")
                # Convert image back to OpenCV format and save it
                image = cv2.cvtColor(np.array(image_pil), cv2.COLOR_RGB2BGR)
                cv2.imshow("image", image)
                cv2.waitKey(0)
                cv2.destroyAllWindows()
                return

    # If no suitable position is found, default to the top-left corner with the smallest font size
    font = ImageFont.truetype(font_path, min_font_size)
    draw.text((10, 10), text, font=font, fill="black")
    image = cv2.cvtColor(np.array(image_pil), cv2.COLOR_RGB2BGR)
    cv2.imwrite(output_path, image)

# Example usage
image_path = impath
bbox = (220, 390, 780, 950)  # Example bounding box (x, y, width, height)
text = "Sip in Style"

add_text_avoiding_bbox(image_path, bbox, text)

# %%
from tools import SearchTools

res=SearchTools.search("What is AI?")

# %%
print(res)
# Out:
# Title: What is AI (Artificial Intelligence)?
# URL: https://exploreai.org/p/ai-definition
# ID: https://exploreai.org/p/ai-definition
# Score: 0.18767638504505157
# Published Date: 2023-01-01
# Author: None
# Text: AI (Artificial Intelligence)
#
# AI (pronounced AYE-EYE) or artificial intelligence is the simulation of human intelligence processes by machines, especially computer systems. These processes include learning (the acquisition of information and rules for using the information), reasoning (using the rules to reach approximate or definite conclusions), and self-correction. Particular applications of AI include expert systems, speech recognition and machine vision.
#
# ...
